# %%
# Copyright Tay Zhi Cong, year 2025

import numpy as np
import matplotlib.pyplot as plt 
from scipy import signal 
import math

# %%
fs=4000
n = np.arange(0,200,1)
h = np.exp(2j*np.pi*500*n/fs)
plt.plot(np.real(h))
plt.figure()
H_k = np.fft.fft(np.exp(2j*np.pi*500*n/fs))
plt.stem(np.abs(H_k))
plt.xlim(0, 200)
# Out:
# (0.0, 200.0)
