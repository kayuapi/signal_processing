# %%
# Copyright Tay Zhi Cong, year 2025

import numpy as np 
import matplotlib.pyplot as plt 
from scipy import signal 
import math
import sys

# %%
n = np.arange(-(4-1/5), 4, 1/5)
y = np.sinc(n)
y = y/sum(y)
print(y.shape)
plt.stem(n, y)
plt.grid(True)

plt.figure()
plt.plot(20*np.log10(abs(np.fft.fft(y, 1024))))
# Out:
# (39,)
