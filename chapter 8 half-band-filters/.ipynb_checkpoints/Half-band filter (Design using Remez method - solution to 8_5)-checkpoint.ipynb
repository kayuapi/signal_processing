# %%
# Copyright Tay Zhi Cong, year 2025

import random
import numpy as np 
import matplotlib.pyplot as plt 
from scipy import signal 
import math
import sys
np.set_printoptions(threshold=sys.maxsize)

# %% [markdown]
# ![8_5](img/8.5.png)

# %% [markdown]
# #### Design a low-pass half-band filter with the following spec:
# transition bandwidth: 0.1 \
# stop-band attenuation: 60dB

# %%
stop_band_attenuation = 60
f_sampling = 1
f_transition = 0.1
f_minus_6db = 0.25

beta = signal.kaiser_beta(stop_band_attenuation) # 1. calculate the kaiser beta
filter_length = math.ceil((f_sampling/f_transition) * (stop_band_attenuation-8)/14) # 2. estimate the filter length : N ~= f_sampling/ f_transition * (Attenuation (in dB) - 8) / 14
print("beta is", beta)
print("filter_length is", filter_length)

filter_length = 41

h = signal.remez(41, [0, 0.25-0.05, 0.25+0.05, 0.5], [1, 0], weight=[1, 1])
print("sum of h is", sum(h))
print(h)
# not needed
# h = h/sum(h)
# Out:
# beta is 5.65326
# filter_length is 38
# sum of h is 0.9996607639401603
# [ 6.47363970e-09 -6.38341749e-04 -2.31052675e-07  1.63018390e-03
#   5.43269451e-07 -3.54896329e-03 -1.20785515e-06  6.77253530e-03
#   1.98566401e-06 -1.18813882e-02 -3.10274443e-06  1.97802055e-02
#   3.86262840e-06 -3.22037193e-02 -4.71085275e-06  5.35107110e-02
#   5.52889397e-06 -9.97246091e-02 -5.67585453e-06  3.16133768e-01
#   5.00006003e-01  3.16133768e-01 -5.67585453e-06 -9.97246091e-02
#   5.52889397e-06  5.35107110e-02 -4.71085275e-06 -3.22037193e-02
#   3.86262840e-06  1.97802055e-02 -3.10274443e-06 -1.18813882e-02
#   1.98566401e-06  6.77253530e-03 -1.20785515e-06 -3.54896329e-03
#   5.43269451e-07  1.63018390e-03 -2.31052675e-07 -6.38341749e-04
#   6.47363970e-09]

# %% [markdown]
# #### stem the impulse response, plot the magnitude spectrum and then the log magnitude spectrum

# %%
ax1 = plt.subplot(3,1,1)
ax1.stem(h)
ff = np.arange(0, 1, 1/1024) * 1
ax2 = plt.subplot(3,1,2)
ax2.plot(ff, abs(np.fft.fft(h, 1024)))
ax2.grid(True)
ax2.minorticks_on()
ax2.grid(which="minor")
ax2 = plt.subplot(3,1,3)
ax2.plot(ff, 20*np.log10(abs(np.fft.fft(h, 1024))))
ax2.grid(True)
ax2.minorticks_on()
ax2.grid(which="minor")

plt.figure()
ax3 = plt.subplot(2,1,1)
ax3.plot(ff, 20*np.log10(abs(np.fft.fft(h, 1024))))
ax3.grid(True)
ax3.minorticks_on()
ax3.grid(which="minor")
ax3.set_xlim(0, 0.25)
ax3.set_ylim(-0.01, 0.01)

ax4 = plt.subplot(2,1,2)
ax4.plot(ff, 20*np.log10(abs(np.fft.fft(h, 1024))))
ax4.grid(True)
ax4.minorticks_on()
ax4.grid(which="minor")
ax4.set_xlim(0.28, 0.33)
ax4.set_ylim(-80, -50)
# Out:
# (-80.0, -50.0)
